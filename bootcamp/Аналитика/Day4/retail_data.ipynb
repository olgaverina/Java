# %% [markdown]
# ## Использование pandas для анализа данных (срезы, группировки, общие сведения о датафрейме, стат. характеристики).

# %%
import pandas as pd
import sys
import warnings
if not sys.warnoptions:
       warnings.simplefilter("ignore")

# %%
data = pd.read_csv('Online Retail.csv', sep = ';', parse_dates = ['InvoiceDate'])

# %%
data.head()
# Out:
#   InvoiceNo StockCode                        Description  Quantity  \
# 0    581483     23843        PAPER CRAFT . LITTLE BIRDIE     80995
# 1    541431     23166     MEDIUM CERAMIC TOP STORAGE JAR     74215
# 2    578841     84826     ASSTD DESIGN 3D PAPER STICKERS     12540
# 3    542504     37413                                NaN      5568
# 4    573008     84077  WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Unnamed: 8
# 0 2011-09-12 09:15:00       2.08     16446.0  United Kingdom         NaN
# 1 2011-01-18 10:01:00       1.04     12346.0  United Kingdom         NaN
# 2 2011-11-25 15:57:00       0.00     13256.0  United Kingdom         NaN
# 3 2011-01-28 12:03:00       0.00         NaN  United Kingdom         NaN
# 4 2011-10-27 12:26:00       0.21     12901.0  United Kingdom         NaN

# %%
df = data.drop(columns = ['Unnamed: 8'])

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 541904   C536757     84347  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360
# 541905    556690     23005         printing smudges/thrown away     -9600
# 541906    556691     23005         printing smudges/thrown away     -9600
# 541907   C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 541908   C581484     23843          PAPER CRAFT . LITTLE BIRDIE    -80995
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 541904 2010-02-12 14:23:00       0.03     15838.0  United Kingdom
# 541905 2011-06-14 10:37:00       0.00         NaN  United Kingdom
# 541906 2011-06-14 10:37:00       0.00         NaN  United Kingdom
# 541907 2011-01-18 10:17:00       1.04     12346.0  United Kingdom
# 541908 2011-09-12 09:27:00       2.08     16446.0  United Kingdom

# %%
df.sample()
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 112243    572913     21326  AGED GLASS SILVER T-LIGHT HOLDER        12
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 112243 2011-10-26 16:21:00       0.65     15993.0  United Kingdom

# %% [markdown]
# ### Общая информация о датафрейме

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df['Quantity'] = df['Quantity'].astype('int')
df['CustomerID'] = df['CustomerID'].astype('str')
df['UnitPrice'] = df['UnitPrice'].astype('float')
df['Country'] = df['Country'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int32
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   541909 non-null  object
#  7   Country      541909 non-null  category
# dtypes: category(1), datetime64[ns](1), float64(1), int32(1), object(4)
# memory usage: 27.4+ MB

# %%
df.describe()
# Out:
#             Quantity      UnitPrice
# count  541909.000000  541909.000000
# mean        9.552250       4.611114
# std       218.081158      96.759853
# min    -80995.000000  -11062.060000
# 25%         1.000000       1.250000
# 50%         3.000000       2.080000
# 75%        10.000000       4.130000
# max     80995.000000   38970.000000

# %%
df.duplicated(subset=['InvoiceNo'])
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 541904    False
# 541905    False
# 541906    False
# 541907    False
# 541908    False
# Length: 541909, dtype: bool

# %% [markdown]
# ### Срезы в данных

# %%
df_UK = df[df['Country'] == 'United Kingdom']

# %%
df[df['Quantity'] <= 1000]
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 116       537841     16014          SMALL CHINESE STYLE SCISSOR      1000
# 117       566028     16014          SMALL CHINESE STYLE SCISSOR      1000
# 118       569815    85099B              JUMBO BAG RED RETROSPOT      1000
# 119       547519     16014          SMALL CHINESE STYLE SCISSOR      1000
# 120       575582    85099B              JUMBO BAG RED RETROSPOT      1000
# ...          ...       ...                                  ...       ...
# 541904   C536757     84347  ROTATING SILVER ANGELS T-LIGHT HLDR     -9360
# 541905    556690     23005         printing smudges/thrown away     -9600
# 541906    556691     23005         printing smudges/thrown away     -9600
# 541907   C541433     23166       MEDIUM CERAMIC TOP STORAGE JAR    -74215
# 541908   C581484     23843          PAPER CRAFT . LITTLE BIRDIE    -80995
#
#                InvoiceDate  UnitPrice CustomerID         Country
# 116    2010-08-12 15:10:00       0.32    13848.0  United Kingdom
# 117    2011-08-09 12:58:00       0.32    13848.0  United Kingdom
# 118    2011-06-10 11:53:00       1.79    15838.0  United Kingdom
# 119    2011-03-23 14:46:00       0.32    16308.0  United Kingdom
# 120    2011-10-11 11:55:00       1.79    16986.0  United Kingdom
# ...                    ...        ...        ...             ...
# 541904 2010-02-12 14:23:00       0.03    15838.0  United Kingdom
# 541905 2011-06-14 10:37:00       0.00        nan  United Kingdom
# 541906 2011-06-14 10:37:00       0.00        nan  United Kingdom
# 541907 2011-01-18 10:17:00       1.04    12346.0  United Kingdom
# 541908 2011-09-12 09:27:00       2.08    16446.0  United Kingdom
#
# [541793 rows x 8 columns]

# %% [markdown]
# ### Группировка данных

# %%
dff = df.groupby(by=["Country"]).sum()
dff
# Out:
#                       Quantity     UnitPrice
# Country
# Australia                83653  4.054750e+03
# Austria                   4827  1.701520e+03
# Bahrain                    260  8.657000e+01
# Belgium                  23152  7.540130e+03
# Brazil                     356  1.426000e+02
# Canada                    2763  9.105800e+02
# Channel Islands           9479  3.738550e+03
# Cyprus                    6317  3.920070e+03
# Czech Republic             592  8.815000e+01
# Denmark                   8188  1.266950e+03
# EIRE                    142637  4.844719e+04
# European Community         497  2.940500e+02
# Finland                  10666  3.786850e+03
# France                  110480  4.303199e+04
# Germany                 117448  3.766600e+04
# Greece                    1556  7.132900e+02
# Hong Kong                 4769  1.224150e+04
# Iceland                   2458  4.812100e+02
# Israel                    4353  1.079040e+03
# Italy                     7999  3.879390e+03
# Japan                    25218  8.148600e+02
# Lebanon                    386  2.424400e+02
# Lithuania                  652  9.944000e+01
# Malta                      944  6.660100e+02
# Netherlands             200128  6.492550e+03
# Norway                   19247  6.529060e+03
# Poland                    3653  1.422270e+03
# Portugal                 16180  1.303754e+04
# RSA                        352  2.481000e+02
# Saudi Arabia                75  2.411000e+01
# Singapore                 5234  2.510889e+04
# Spain                    26824  1.263345e+04
# Sweden                   35637  1.806830e+03
# Switzerland              30325  6.813690e+03
# USA                       1034  6.449800e+02
# United Arab Emirates       982  2.298900e+02
# United Kingdom         4263829  2.245715e+06
# Unspecified               3300  1.204010e+03

# %%
dff.index
# Out:
# CategoricalIndex(['Australia', 'Austria', 'Bahrain', 'Belgium', 'Brazil',
#                   'Canada', 'Channel Islands', 'Cyprus', 'Czech Republic',
#                   'Denmark', 'EIRE', 'European Community', 'Finland', 'France',
#                   'Germany', 'Greece', 'Hong Kong', 'Iceland', 'Israel',
#                   'Italy', 'Japan', 'Lebanon', 'Lithuania', 'Malta',
#                   'Netherlands', 'Norway', 'Poland', 'Portugal', 'RSA',
#                   'Saudi Arabia', 'Singapore', 'Spain', 'Sweden',
#                   'Switzerland', 'USA', 'United Arab Emirates',
#                   'United Kingdom', 'Unspecified'],
#                  categories=['Australia', 'Austria', 'Bahrain', 'Belgium', 'Brazil', 'Canada', 'Channel Islands', 'Cyprus', ...], ordered=False, name='Country', dtype='category')
